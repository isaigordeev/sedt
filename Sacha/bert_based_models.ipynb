# %%
"""For working in Google Colab"""
# from google.colab import drive
# drive.mount('/content/drive')
# cd /content/drive/MyDrive/Colab\ Notebooks
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
"""Importing Libraries"""
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from PreprocessData import *
from transformers import Trainer, TrainingArguments
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       5 from torch.utils.data import DataLoader, Dataset
#       6 from PreprocessData import *
# ----> 7 from transformers import Trainer, TrainingArguments
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1766, in _LazyModule.__getattr__(self, name)
#    1764     value = Placeholder
#    1765 elif name in self._class_to_module.keys():
# -> 1766     module = self._get_module(self._class_to_module[name])
#    1767     value = getattr(module, name)
#    1768 elif name in self._modules:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1778, in _LazyModule._get_module(self, module_name)
#    1776 def _get_module(self, module_name: str):
#    1777     try:
# -> 1778         return importlib.import_module("." + module_name, self.__name__)
#    1779     except Exception as e:
#    1780         raise RuntimeError(
#    1781             f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1782             f" traceback):\n{e}"
#    1783         ) from e
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\trainer.py:42
#      37 from typing import TYPE_CHECKING, Any, Callable, Dict, List, Optional, Tuple, Union
#      40 # Integrations must be imported before ML frameworks:
#      41 # isort: off
# ---> 42 from .integrations import (
#      43     get_reporting_integration_callbacks,
#      44     hp_params,
#      45 )
#      47 # isort: on
#      49 import huggingface_hub.utils as hf_hub_utils
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1766, in _LazyModule.__getattr__(self, name)
#    1764     value = Placeholder
#    1765 elif name in self._class_to_module.keys():
# -> 1766     module = self._get_module(self._class_to_module[name])
#    1767     value = getattr(module, name)
#    1768 elif name in self._modules:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1778, in _LazyModule._get_module(self, module_name)
#    1776 def _get_module(self, module_name: str):
#    1777     try:
# -> 1778         return importlib.import_module("." + module_name, self.__name__)
#    1779     except Exception as e:
#    1780         raise RuntimeError(
#    1781             f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1782             f" traceback):\n{e}"
#    1783         ) from e
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\integrations\integration_utils.py:36
#      33 import numpy as np
#      34 import packaging.version
# ---> 36 from .. import PreTrainedModel, TFPreTrainedModel
#      37 from .. import __version__ as version
#      38 from ..utils import (
#      39     PushToHubMixin,
#      40     flatten_dict,
#    (...)
#      45     logging,
#      46 )
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1766, in _LazyModule.__getattr__(self, name)
#    1764     value = Placeholder
#    1765 elif name in self._class_to_module.keys():
# -> 1766     module = self._get_module(self._class_to_module[name])
#    1767     value = getattr(module, name)
#    1768 elif name in self._modules:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1778, in _LazyModule._get_module(self, module_name)
#    1776 def _get_module(self, module_name: str):
#    1777     try:
# -> 1778         return importlib.import_module("." + module_name, self.__name__)
#    1779     except Exception as e:
#    1780         raise RuntimeError(
#    1781             f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1782             f" traceback):\n{e}"
#    1783         ) from e
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\modeling_utils.py:48
#      46 from .generation import GenerationConfig, GenerationMixin
#      47 from .integrations import PeftAdapterMixin, deepspeed_config, is_deepspeed_zero3_enabled
# ---> 48 from .loss.loss_utils import LOSS_MAPPING
#      49 from .pytorch_utils import (  # noqa: F401
#      50     Conv1D,
#      51     apply_chunking_to_forward,
#    (...)
#      57     prune_linear_layer,
#      58 )
#      59 from .quantizers import AutoHfQuantizer, HfQuantizer
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\loss\loss_utils.py:19
#      16 import torch.nn as nn
#      17 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 19 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      20 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#      21 from .loss_rt_detr import RTDetrForObjectDetectionLoss
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\loss\loss_deformable_detr.py:4
#       1 import torch
#       2 import torch.nn as nn
# ----> 4 from ..image_transforms import center_to_corners_format
#       5 from ..utils import is_scipy_available
#       6 from .loss_for_object_detection import (
#       7     HungarianMatcher,
#       8     ImageLoss,
#    (...)
#      11     sigmoid_focal_loss,
#      12 )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\image_transforms.py:50
#      47     import torch
#      49 if is_tf_available():
# ---> 50     import tensorflow as tf
#      52 if is_flax_available():
#      53     import jax.numpy as jnp
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
#      13 from tensorflow._api.v2.__internal__ import feature_column
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\_api\v2\__internal__\distribute\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.distribute namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__.distribute import combinations
#       9 from tensorflow._api.v2.__internal__.distribute import interim
#      10 from tensorflow._api.v2.__internal__.distribute import multi_process_runner
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\_api\v2\__internal__\distribute\combinations\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.distribute.combinations namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.distribute.combinations import env # line: 456
#       9 from tensorflow.python.distribute.combinations import generate # line: 365
#      10 from tensorflow.python.distribute.combinations import in_main_process # line: 418
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\combinations.py:33
#      29 import six
#      32 from tensorflow.python.client import session
# ---> 33 from tensorflow.python.distribute import collective_all_reduce_strategy
#      34 from tensorflow.python.distribute import distribute_lib
#      35 from tensorflow.python.distribute import multi_process_runner
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\collective_all_reduce_strategy.py:25
#      23 from tensorflow.core.protobuf import tensorflow_server_pb2
#      24 from tensorflow.python.distribute import collective_util
# ---> 25 from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#      26 from tensorflow.python.distribute import cross_device_utils
#      27 from tensorflow.python.distribute import device_util
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\cross_device_ops.py:28
#      26 from tensorflow.python.client import device_lib
#      27 from tensorflow.python.distribute import collective_util
# ---> 28 from tensorflow.python.distribute import cross_device_utils
#      29 from tensorflow.python.distribute import device_util
#      30 from tensorflow.python.distribute import distribute_utils
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\cross_device_utils.py:22
#      19 from typing import Callable, List, Optional, Union
#      21 from tensorflow.python.distribute import collective_util
# ---> 22 from tensorflow.python.distribute import values as value_lib
#      23 from tensorflow.python.eager import backprop_util
#      24 from tensorflow.python.eager import context
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\values.py:23
#      21 from tensorflow.core.protobuf import struct_pb2
#      22 from tensorflow.python.distribute import device_util
# ---> 23 from tensorflow.python.distribute import distribute_lib
#      24 from tensorflow.python.distribute import packed_distributed_variable as packed
#      25 from tensorflow.python.distribute import reduce_util
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:205
#     203 from tensorflow.python.autograph.core import ag_ctx as autograph_ctx
#     204 from tensorflow.python.autograph.impl import api as autograph
# --> 205 from tensorflow.python.data.ops import dataset_ops
#     206 from tensorflow.python.distribute import collective_util
#     207 from tensorflow.python.distribute import device_util
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\__init__.py:21
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\experimental\__init__.py:99
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      95 @@UNKNOWN_CARDINALITY
#      96 """
#      98 # pylint: disable=unused-import
# ---> 99 from tensorflow.python.data.experimental import service
#     100 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#     101 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\experimental\service\__init__.py:419
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     416   job of ParameterServerStrategy).
#     417 """
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:23
#      21 from tensorflow.core.protobuf import data_service_pb2
#      22 from tensorflow.python import tf2
# ---> 23 from tensorflow.python.data.experimental.ops import compression_ops
#      24 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      25 from tensorflow.python.data.experimental.service import _pywrap_utils_exp
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\experimental\ops\compression_ops.py:16
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Ops for compressing and uncompressing dataset elements."""
# ---> 16 from tensorflow.python.data.util import structure
#      17 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      20 def compress(element):
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\util\structure.py:32
#      30 from tensorflow.python.ops import resource_variable_ops
#      31 from tensorflow.python.ops import tensor_array_ops
# ---> 32 from tensorflow.python.ops.ragged import ragged_tensor
#      33 from tensorflow.python.platform import tf_logging as logging
#      34 from tensorflow.python.types import internal
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\ragged\__init__.py:28
#       1 # Copyright 2018 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Ragged Tensors.
#      16
#      17 This package defines ops for manipulating ragged tensors (`tf.RaggedTensor`),
#    (...)
#      26 API docstring: tensorflow.ragged
#      27 """
# ---> 28 from tensorflow.python.ops.ragged import ragged_tensor
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\ragged\ragged_tensor.py:3149
#    3144 RaggedOrDense = typing.Union[Ragged, core_types.TensorLike]
#    3146 # RaggedTensor must import ragged_ops to ensure that all dispatched ragged ops
#    3147 # are registered. Ragged ops import RaggedTensor, so import at bottom of the
#    3148 # file to avoid a partially-initialized module error.
# -> 3149 from tensorflow.python.ops.ragged import ragged_ops  # pylint: disable=unused-import, g-bad-import-order, g-import-not-at-top
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\ragged\ragged_ops.py:41
#      39 from tensorflow.python.ops.ragged import ragged_gather_ops
#      40 from tensorflow.python.ops.ragged import ragged_getitem
# ---> 41 from tensorflow.python.ops.ragged import ragged_image_ops
#      42 from tensorflow.python.ops.ragged import ragged_map_ops
#      43 from tensorflow.python.ops.ragged import ragged_math_ops
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\ragged\ragged_image_ops.py:24
#      22 from tensorflow.python.ops import array_ops
#      23 from tensorflow.python.ops import cond
# ---> 24 from tensorflow.python.ops import image_ops
#      25 from tensorflow.python.ops import map_fn
#      26 from tensorflow.python.ops import math_ops
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\image_ops.py:159
#     156 # go/tf-wildcard-import
#     157 # pylint: disable=wildcard-import
#     158 from tensorflow.python.ops.gen_image_ops import *
# --> 159 from tensorflow.python.ops.image_ops_impl import *
#     160 # pylint: enable=wildcard-import
#     161
#     162 # TODO(drpng): remove these once internal use has discontinued.
#     163 # pylint: disable=unused-import
#     164 from tensorflow.python.ops.image_ops_impl import _Check3DImage
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\image_ops_impl.py:54
#      51 from tensorflow.python.util import numpy_compat
#      52 from tensorflow.python.util.tf_export import tf_export
# ---> 54 ops.NotDifferentiable('RandomCrop')
#      55 # TODO(b/31222613): This op may be differentiable, and there may be
#      56 # latent bugs here.
#      57 ops.NotDifferentiable('HSVToRGB')
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\framework\ops.py:1754, in no_gradient(op_type)
#    1752 if not isinstance(op_type, str):
#    1753   raise TypeError("op_type must be a string")
# -> 1754 gradient_registry.register(None, op_type)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\framework\registry.py:65, in Registry.register(self, candidate, name)
#      62 logging.vlog(1, "Registering %s (%s) in %s.", name, candidate, self._name)
#      63 # stack trace is [this_function, Register(), user_function,...]
#      64 # so the user function is #2.
# ---> 65 stack = traceback.extract_stack(limit=3)
#      66 stack_index = min(2, len(stack) - 1)
#      67 if stack_index >= 0:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\traceback.py:231, in extract_stack(f, limit)
#     229 if f is None:
#     230     f = sys._getframe().f_back
# --> 231 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     232 stack.reverse()
#     233 return stack
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\traceback.py:393, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     390     for f, lineno in frame_gen:
#     391         yield f, (lineno, None, None, None)
# --> 393 return klass._extract_from_extended_frame_gen(
#     394     extended_frame_gen(), limit=limit, lookup_lines=lookup_lines,
#     395     capture_locals=capture_locals)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\traceback.py:432, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     428     result.append(FrameSummary(
#     429         filename, lineno, name, lookup_line=False, locals=f_locals,
#     430         end_lineno=end_lineno, colno=colno, end_colno=end_colno))
#     431 for filename in fnames:
# --> 432     linecache.checkcache(filename)
#     433 # If immediate lookup was desired, trigger lookups now.
#     434 if lookup_lines:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\linecache.py:72, in checkcache(filename)
#      70     continue   # no-op for files loaded via a __loader__
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except OSError:
#      74     cache.pop(filename, None)
#
# KeyboardInterrupt:

# %%
test_or_final = 0 # 0 for test, 1 for final
from transformers import LongformerForSequenceClassification, LongformerTokenizer
model_name = "allenai/longformer-base-4096"
tokenizer = LongformerTokenizer.from_pretrained(model_name)

if test_or_final:
    """Praparaing and tokenizing all the data for final submission"""
    train_data = read_csv("challenge_data/train_tweets/", tokenizer, 32)
else:
    """Praparaing and tokenizing une file for testing"""
    train_data = process_csv_groupe_by_period(tokenizer, "challenge_data/train_tweets/ArgentinaBelgium72.csv", 32, 4096)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8000bc2c42a6> in <cell line: 5>()
#       3 model_name = "allenai/longformer-base-4096"
#       4 tokenizer = LongformerTokenizer.from_pretrained(model_name)
# ----> 5 train_data = read_csv("challenge_data/train_tweets/", tokenizer, 32)
#
# /content/drive/MyDrive/Colab Notebooks/PreprocessData.py in read_csv(folder_path, tokenizer, l)
#     137     li = []
#     138     for filename in os.listdir(folder_path):
# --> 139         df = process_csv_groupe_by_period(tokenizer, folder_path + filename, l)
#     140         li.append(df)
#     141     df = pd.concat(li, ignore_index=True)
#
# /content/drive/MyDrive/Colab Notebooks/PreprocessData.py in process_csv_groupe_by_period(tokenizer, file_path, l, piece_size)
#     102
#     103     # Apply preprocessing to each tweet
# --> 104     df['Tweet'] = df['Tweet'].apply(preprocess_text)
#     105
#     106     def tokenize_tweet(tweet):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# /content/drive/MyDrive/Colab Notebooks/PreprocessData.py in preprocess_text(text)
#      37     # Lemmatization
#      38     lemmatizer = WordNetLemmatizer()
# ---> 39     words = [lemmatizer.lemmatize(word) for word in words]
#      40     return ' '.join(words)
#      41
#
# /content/drive/MyDrive/Colab Notebooks/PreprocessData.py in <listcomp>(.0)
#      37     # Lemmatization
#      38     lemmatizer = WordNetLemmatizer()
# ---> 39     words = [lemmatizer.lemmatize(word) for word in words]
#      40     return ' '.join(words)
#      41
#
# /usr/local/lib/python3.10/dist-packages/nltk/stem/wordnet.py in lemmatize(self, word, pos)
#      83         :return: The shortest lemma of `word`, for the given `pos`.
#      84         """
# ---> 85         lemmas = self._morphy(word, pos)
#      86         return min(lemmas, key=len) if lemmas else word
#      87
#
# /usr/local/lib/python3.10/dist-packages/nltk/stem/wordnet.py in _morphy(self, form, pos, check_exceptions)
#      39         from nltk.corpus import wordnet as wn
#      40
# ---> 41         return wn._morphy(form, pos, check_exceptions)
#      42
#      43     def morphy(self, form, pos=None, check_exceptions=True):
#
# /usr/local/lib/python3.10/dist-packages/nltk/corpus/reader/wordnet.py in _morphy(self, form, pos, check_exceptions)
#    2107
#    2108         # 2. Return all that are in the database (and check the original too)
# -> 2109         return filter_forms([form] + forms)
#    2110
#    2111     #############################################################
#
# /usr/local/lib/python3.10/dist-packages/nltk/corpus/reader/wordnet.py in filter_forms(forms)
#    2093             for form in forms:
#    2094                 if form in self._lemma_pos_offset_map:
# -> 2095                     if pos in self._lemma_pos_offset_map[form]:
#    2096                         if form not in seen:
#    2097                             result.append(form)
#
# KeyboardInterrupt:

# %%
def compute_metrics_from_predictions(predictions, labels):
    predicted_classes = np.argmax(predictions, axis=-1)
    accuracy = (predicted_classes == labels).mean()
    return {"accuracy": accuracy}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class CustomDataset(Dataset):
    def __init__(self, tweets, labels):
        self.text = [torch.tensor(tweet, dtype=torch.long) for tweet in tweets]
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            "input_ids": self.text[idx],  # Required key for BERT input
            "attention_mask": torch.ones_like(self.text[idx]),  # Add attention mask
            "labels": self.labels[idx],  # Required key for classification
        }

dataset_train = CustomDataset(train_data['Tweet'], train_data['EventType'])
train_loader = DataLoader(dataset_train, batch_size=512, shuffle=True, pin_memory=True)

# %%
model = LongformerForSequenceClassification.from_pretrained(model_name, num_labels=2)
model.to(device)


for param in model.longformer.parameters():
    param.requires_grad = False


training_args = TrainingArguments(
    output_dir='./results',
    fp16=True,
    num_train_epochs=1,
    weight_decay=1e-12,
    logging_dir='./logs',
    evaluation_strategy='no',
    gradient_accumulation_steps=1  # Accumulate gradients for larger effective batch size
)

trainer = Trainer(
    model = model,
    args = training_args,
    train_dataset = dataset_train
)

trainer.train()

pred_output = trainer.predict(dataset_train)
logits = pred_output.predictions
labels = pred_output.label_ids
metrics = compute_metrics_from_predictions(logits, labels)

print("Training Accuracy:")
print(metrics)
# Out:
# Some weights of LongformerForSequenceClassification were not initialized from the model checkpoint at allenai/longformer-base-4096 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/597M [00:00<?, ?B/s]
#     <div>
#
#       <progress value='298' max='298' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [298/298 11:24, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Training Accuracy:
# {'accuracy': 0.6090604026845637}
